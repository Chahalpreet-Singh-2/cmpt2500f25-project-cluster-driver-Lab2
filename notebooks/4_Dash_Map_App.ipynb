# %% [markdown]
# # **4. **

# %%
# !pip install dash
# !pip install dash-leaflet
# !pip install geocoder
# !pip install plotly
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from scipy import stats
import dash
from dash import html  # Updated import
from dash import dcc  # Updated import
import dash_leaflet as dl
from dash.dependencies import Input, Output, State
import geocoder
import plotly.express as px
import plotly.graph_objects as go
from geopy.extra.rate_limiter import RateLimiter # to avoid overloading the server
from functools import lru_cache #used to cache the results
# Out:
# Requirement already satisfied: dash in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from dash) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.12/dist-packages (from dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dash) (2.32.4)
# Requirement already satisfied: retrying in /usr/local/lib/python3.12/dist-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (2025.10.5)
# Requirement already satisfied: dash-leaflet in /usr/local/lib/python3.12/dist-packages (1.1.3)
# Requirement already satisfied: dash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dash-leaflet) (3.2.0)
# Requirement already satisfied: dash-extensions>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dash-leaflet) (2.0.4)
# Requirement already satisfied: dash_svg in /usr/local/lib/python3.12/dist-packages (from dash-leaflet) (0.0.12)
# Requirement already satisfied: protobuf>=6.30.2 in /usr/local/lib/python3.12/dist-packages (from dash-leaflet) (6.32.1)
# Requirement already satisfied: geobuf>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dash-leaflet) (2.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from dash-leaflet) (6.0.3)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.12/dist-packages (from dash-leaflet) (3.1.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from dash>=3.0.0->dash-leaflet) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.12/dist-packages (from dash>=3.0.0->dash-leaflet) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from dash>=3.0.0->dash-leaflet) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash>=3.0.0->dash-leaflet) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from dash>=3.0.0->dash-leaflet) (4.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dash>=3.0.0->dash-leaflet) (2.32.4)
# Requirement already satisfied: retrying in /usr/local/lib/python3.12/dist-packages (from dash>=3.0.0->dash-leaflet) (1.4.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash>=3.0.0->dash-leaflet) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash>=3.0.0->dash-leaflet) (75.2.0)
# Requirement already satisfied: more-itertools>=10.6.0 in /usr/local/lib/python3.12/dist-packages (from dash-extensions>=2.0.0->dash-leaflet) (10.8.0)
# Requirement already satisfied: jsbeautifier>=1.15.4 in /usr/local/lib/python3.12/dist-packages (from dash-extensions>=2.0.0->dash-leaflet) (1.15.4)
# Requirement already satisfied: Flask-Caching>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from dash-extensions>=2.0.0->dash-leaflet) (2.3.1)
# Requirement already satisfied: dataclass-wizard>=0.35.0 in /usr/local/lib/python3.12/dist-packages (from dash-extensions>=2.0.0->dash-leaflet) (0.35.1)
# Requirement already satisfied: pydantic>=2.10.6 in /usr/local/lib/python3.12/dist-packages (from dash-extensions>=2.0.0->dash-leaflet) (2.11.10)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from geobuf>=2.0.0->dash-leaflet) (8.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from geobuf>=2.0.0->dash-leaflet) (1.17.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=3.0.0->dash-leaflet) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=3.0.0->dash-leaflet) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=3.0.0->dash-leaflet) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=3.0.0->dash-leaflet) (3.0.3)
# Requirement already satisfied: cachelib>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask-Caching>=2.3.1->dash-extensions>=2.0.0->dash-leaflet) (0.13.0)
# Requirement already satisfied: editorconfig>=0.12.2 in /usr/local/lib/python3.12/dist-packages (from jsbeautifier>=1.15.4->dash-extensions>=2.0.0->dash-leaflet) (0.17.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash>=3.0.0->dash-leaflet) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash>=3.0.0->dash-leaflet) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.6->dash-extensions>=2.0.0->dash-leaflet) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.6->dash-extensions>=2.0.0->dash-leaflet) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.6->dash-extensions>=2.0.0->dash-leaflet) (0.4.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash>=3.0.0->dash-leaflet) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=3.0.0->dash-leaflet) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=3.0.0->dash-leaflet) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=3.0.0->dash-leaflet) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=3.0.0->dash-leaflet) (2025.10.5)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.12/dist-packages (1.38.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from geocoder) (8.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from geocoder) (1.0.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.12/dist-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from geocoder) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from geocoder) (1.17.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->geocoder) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->geocoder) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->geocoder) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->geocoder) (2025.10.5)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)

# %%
# Load the dataframe
df = pd.read_csv('Final_features.csv')
df.head()
# Out:
#                              listing_id                  listing_heading  \
# 0  f5b663d2-4896-11ef-a15b-8b4423f1ff08     1987 IROC Z  350 Auto T-Tops
# 1  a9f565e6-4712-11ef-a23f-79dc25c5e601                              NaN
# 2  03d18c58-253a-11ef-8f33-8905b4a2f000  1989 Cadillac DeVille Sedan FWD
# 3  2d12630b-460e-11ee-89c4-e5b3161d4741  1989 Cadillac DeVille Sedan FWD
# 4  53a8e550-47cd-11ef-8587-f926ecb61035  1989 Camaro IROC 350 Auto T-Top
#
#   listing_type                                        listing_url  \
# 0       Active  https://www.kijiji.ca/v-cars-trucks/edmonton/1...
# 1         Sold  https://www.redlinemotors.ca/vehicle-details/1...
# 2       Active  https://www.sweetheartmotor.com/cars/used/1989...
# 3       Active  https://www.sweetheartmotor.com/cars/used/1989...
# 4       Active  https://www.kijiji.ca/v-cars-trucks/edmonton/1...
#
#   listing_first_date  days_on_market  dealer_id  \
# 0     7/22/2024 0:00               9   11152931
# 1     7/20/2024 0:00               4   11131329
# 2      6/7/2024 0:00              54   11161704
# 3     8/28/2023 0:00             338   11128265
# 4     7/21/2024 0:00              10   11152931
#
#                                dealer_name             dealer_street  \
# 0  David T's Camaro & Firebird Auto Center           10611 201 St NW
# 1                         Redlinemotors.Ca  14421 Mark Messier Trail
# 2  Gateway Auto & Rv Sales & Financing Ltd      5404 Gateway Blvd NW
# 3                            Credit Angels      5404 Gateway Blvd NW
# 4  David T's Camaro & Firebird Auto Center           10611 201 St NW
#
#   dealer_city  ...                            price_history_delimited  \
# 0    Edmonton  ...                            2024-07-22,11500,230860
# 1    Edmonton  ...                              2024-07-20,8700,48905
# 2    Edmonton  ...                             2024-06-07,6000,174640
# 3    Edmonton  ...  2023-08-28,4500,174640:2023-09-13,5900,174640:...
# 4    Edmonton  ...                             2024-07-21,8500,288000
#
#   distance_to_dealer location_score  listing_dropoff_date   latitude  \
# 0               9.84              5                   NaN  53.549233
# 1               8.30              5        7/24/2024 0:00  53.604536
# 2               5.71              4                   NaN  53.492482
# 3               5.71              5                   NaN  53.492482
# 4               9.84              5                   NaN  53.549233
#
#     longitude total_vehicles_sold  most_sold_brand total_revenue  \
# 0 -113.666536                 0.0              NaN           NaN
# 1 -113.578942                43.0             Ford      428200.0
# 2 -113.493143                70.0        Chevrolet     3266527.0
# 3 -113.493143                34.0            Dodge      243171.0
# 4 -113.666536                 0.0              NaN           NaN
#
#    avg_days_on_market
# 0                  11
# 1                 108
# 2                  33
# 3                  94
# 4                  11
#
# [5 rows x 52 columns]

# %%
app = dash.Dash(__name__)
app.layout = html.Div([
    html.Div([
        dcc.Input(id="search-input", type="text", placeholder="Search for a dealership..."),
        html.Button("Search", id="search-button")
    ], style={'display': 'flex', 'justifyContent': 'center', 'marginBottom': '10px'}),

    dcc.Graph(id='plotly-map', figure={},
              config={'scrollZoom': True})  # Add config for zoom on click
])
@app.callback(
    Output('plotly-map', 'figure'),
    [Input("search-button", "n_clicks")],  # Triggered by the search button
    [State("search-input", "value")]     # Get the search term
)
def update_plotly_map(n_clicks, search_term):
    filtered_df = df  # Start with the full dataset

    if search_term:  # If a search term is provided
        # Filter the DataFrame based on the search term (dealer_name)
        filtered_df = df[df['dealer_name'].str.contains(search_term, case=False)]

    fig = px.scatter_mapbox(
        filtered_df,
        lat="latitude",
        lon="longitude",
        hover_name="dealer_name",
        size_max=15,
        zoom=11,
        mapbox_style="open-street-map",
        color="total_vehicles_sold",
        color_continuous_scale="Viridis",
        range_color=[0, 3000],
        custom_data=["dealer_postal_code", "total_vehicles_sold", "most_sold_brand", "total_revenue", "avg_days_on_market"]
    )

    min_marker_size = 12
    max_marker_size = 30
    scaling_factor = (max_marker_size - min_marker_size) / max(filtered_df['total_vehicles_sold'])

    fig.update_traces(
        marker=dict(
            size=min_marker_size + filtered_df['total_vehicles_sold'] * scaling_factor,
            opacity=0.7
        ),
        hovertemplate="<br>".join([
            "<b>%{hovertext}</b>",
            '\n',
            "Dealer Postal Code: %{customdata[0]}",
            "Total Vehicles Sold: %{customdata[1]}",
            "Most Sold Brand: %{customdata[2]}",
            "Total Revenue: ${%{customdata[3]:,.0f}}",
            "Average Days on Market: %{customdata[4]} days"
        ])
    )

    fig.update_layout(margin={"r": 0, "t": 0, "l": 0, "b": 0},
                      showlegend=True,
                      mapbox=dict(
                          center=dict(lat=53.5461, lon=-113.4938),
                          zoom=9,
                          uirevision='foo'
                      )
                      )

    return fig


if __name__ == '__main__':
    app.run(debug=True)
